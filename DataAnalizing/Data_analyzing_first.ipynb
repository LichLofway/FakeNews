# %%
import pandas as pd
import numpy as np

# %%
# !wget -O True.csv https://www.dropbox.com/scl/fi/odl1rjv9ttmg4f3mjk55z/True.csv?rlkey=9d5lv7ltc1ob9mlo9iionemrm&st=tzc6sp4n&dl=0
# !wget -O False.csv https://www.dropbox.com/scl/fi/303jbuwuytw9cjm9u6iyf/Fake.csv?rlkey=948fk1wbt34hppldi80vnnl9c&st=mpqkmljo&dl=0
# Out:
# --2024-08-21 17:05:00--  https://www.dropbox.com/scl/fi/odl1rjv9ttmg4f3mjk55z/True.csv?rlkey=9d5lv7ltc1ob9mlo9iionemrm
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com/cd/0/inline/CZEOfb1Gggk58E6VNv1RBhzXtSSEIvigQ_XH1hRxXYI5qXcMRhSkTaOBnm0OV758JZrEbPMV8_acDZl6B_-jinVvjchyxtwFZwfiCIIUYrZIaEtSY0M3KHKh9v-6aqASl7022tjy-IzXMrj49ZxmdgaD/file# [following]
# --2024-08-21 17:05:01--  https://ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com/cd/0/inline/CZEOfb1Gggk58E6VNv1RBhzXtSSEIvigQ_XH1hRxXYI5qXcMRhSkTaOBnm0OV758JZrEbPMV8_acDZl6B_-jinVvjchyxtwFZwfiCIIUYrZIaEtSY0M3KHKh9v-6aqASl7022tjy-IzXMrj49ZxmdgaD/file
# Resolving ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com (ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com (ucba8ff6228c9ac010ca6099137b.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53582940 (51M) [text/plain]
# Saving to: ‘True.csv’
#
# True.csv            100%[===================>]  51.10M   148MB/s    in 0.3s
#
# 2024-08-21 17:05:02 (148 MB/s) - ‘True.csv’ saved [53582940/53582940]
#
# --2024-08-21 17:05:02--  https://www.dropbox.com/scl/fi/303jbuwuytw9cjm9u6iyf/Fake.csv?rlkey=948fk1wbt34hppldi80vnnl9c
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com/cd/0/inline/CZGu0LJWyesi7dSeOvWFQlPEZnZLmc49voPddYbPb7kyDhsb_BTj2Csj6vpxtinU83Rw94lqZkEH0Hiaj3YqlnRoNIIfRChGzDlR6fYmw5ae6mUY_MyMjkOZ8T7plSUA-UmNXfASmV1Mw1bLaWA2jI7U/file# [following]
# --2024-08-21 17:05:02--  https://uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com/cd/0/inline/CZGu0LJWyesi7dSeOvWFQlPEZnZLmc49voPddYbPb7kyDhsb_BTj2Csj6vpxtinU83Rw94lqZkEH0Hiaj3YqlnRoNIIfRChGzDlR6fYmw5ae6mUY_MyMjkOZ8T7plSUA-UmNXfASmV1Mw1bLaWA2jI7U/file
# Resolving uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com (uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601d:15::a27d:50f
# Connecting to uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com (uca7a477b397e730d372516cfb84.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62789876 (60M) [text/plain]
# Saving to: ‘False.csv’
#
# False.csv           100%[===================>]  59.88M   174MB/s    in 0.3s
#
# 2024-08-21 17:05:03 (174 MB/s) - ‘False.csv’ saved [62789876/62789876]

# %%
#Readin input files
dft = pd.read_csv("True.csv")
dff = pd.read_csv("False.csv")

# %%
dft.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
dff.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
dft.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
dft.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
#New column reliability
dft = dft.assign(reliability=[1 for i in range(len(dft))])
dff = dff.assign(reliability=[0 for i in range(len(dff))])

# %%
#Concatinating real and fake news_dataframes
df = pd.concat([dft, dff])
df.index = range(0,len(df))

# %%
df[df['reliability'] == 0].head()
# Out:
#                                                    title  \
# 21417   Donald Trump Sends Out Embarrassing New Year’...
# 21418   Drunk Bragging Trump Staffer Started Russian ...
# 21419   Sheriff David Clarke Becomes An Internet Joke...
# 21420   Trump Is So Obsessed He Even Has Obama’s Name...
# 21421   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                     text subject  \
# 21417  Donald Trump just couldn t wish all Americans ...    News
# 21418  House Intelligence Committee Chairman Devin Nu...    News
# 21419  On Friday, it was revealed that former Milwauk...    News
# 21420  On Christmas day, Donald Trump announced that ...    News
# 21421  Pope Francis used his annual Christmas Day mes...    News
#
#                     date  reliability
# 21417  December 31, 2017            0
# 21418  December 31, 2017            0
# 21419  December 30, 2017            0
# 21420  December 29, 2017            0
# 21421  December 25, 2017            0

# %%
df[df['reliability'] == 1].head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  reliability
# 0  December 31, 2017             1
# 1  December 29, 2017             1
# 2  December 31, 2017             1
# 3  December 30, 2017             1
# 4  December 29, 2017             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        44898 non-null  object
#  1   text         44898 non-null  object
#  2   subject      44898 non-null  object
#  3   date         44898 non-null  object
#  4   reliability  44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB

# %%
df.tail(10)
# Out:
#                                                    title  \
# 44888  Seven Iranians freed in the prisoner swap have...
# 44889                      #Hashtag Hell & The Fake Left
# 44890  Astroturfing: Journalist Reveals Brainwashing ...
# 44891          The New American Century: An Era of Fraud
# 44892  Hillary Clinton: ‘Israel First’ (and no peace ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 44888  21st Century Wire says This week, the historic...  Middle-east
# 44889   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 44890  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# 44891  Paul Craig RobertsIn the last years of the 20t...  Middle-east
# 44892  Robert Fantina CounterpunchAlthough the United...  Middle-east
# 44893  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 44894  21st Century Wire says It s a familiar theme. ...  Middle-east
# 44895  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 44896  21st Century Wire says Al Jazeera America will...  Middle-east
# 44897  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  reliability
# 44888  January 20, 2016            0
# 44889  January 19, 2016            0
# 44890  January 19, 2016            0
# 44891  January 19, 2016            0
# 44892  January 18, 2016            0
# 44893  January 16, 2016            0
# 44894  January 16, 2016            0
# 44895  January 15, 2016            0
# 44896  January 14, 2016            0
# 44897  January 12, 2016            0

# %%
#Deleting noize symbols from dataframe "df" on column "content_field"
def standardize_text(df, content_field):
    df[content_field] = df[content_field].str.replace(r"[^A-Za-z0-9\(\),!?@\'\`\"_n]", " ")
    df[content_field] = df[content_field].replace(r'[^?!\.\w\s]',' ',regex=True)
    df[content_field] = df[content_field].str.lower()
    return df

# %%
standardize_text(df, "title")
standardize_text(df, "text")
standardize_text(df, "subject")
standardize_text(df, "date")
# Out:
#                                                    title  \
# 0      as u.s. budget fight looms  republicans flip t...
# 1      u.s. military to accept transgender recruits o...
# 2      senior u.s. republican senator   let mr. muell...
# 3      fbi russia probe helped by australian diplomat...
# 4      trump wants postal service to charge  much mor...
# ...                                                  ...
# 44893  mcpain  john mccain furious that iran treated ...
# 44894  justice? yahoo settles e mail privacy class ac...
# 44895  sunnistan  us and allied  safe zone  plan to t...
# 44896  how to blow  700 million  al jazeera america f...
# 44897  10 u.s. navy sailors held by iranian military ...
#
#                                                     text       subject  \
# 0      washington  reuters    the head of a conservat...  politicsnews
# 1      washington  reuters    transgender people will...  politicsnews
# 2      washington  reuters    the special counsel inv...  politicsnews
# 3      washington  reuters    trump campaign adviser ...  politicsnews
# 4      seattle washington  reuters    president donal...  politicsnews
# ...                                                  ...           ...
# 44893  21st century wire says as 21wire reported earl...   middle east
# 44894  21st century wire says it s a familiar theme. ...   middle east
# 44895  patrick henningsen  21st century wireremember ...   middle east
# 44896  21st century wire says al jazeera america will...   middle east
# 44897  21st century wire says as 21wire predicted in ...   middle east
#
#                      date  reliability
# 0      december 31  2017             1
# 1      december 29  2017             1
# 2      december 31  2017             1
# 3      december 30  2017             1
# 4      december 29  2017             1
# ...                   ...          ...
# 44893    january 16  2016            0
# 44894    january 16  2016            0
# 44895    january 15  2016            0
# 44896    january 14  2016            0
# 44897    january 12  2016            0
#
# [44898 rows x 5 columns]

# %%
import re
import string
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Bring the text to one view
def lemmatization(df, content_field):
  lemmatizer=WordNetLemmatizer()
  corpus = []
  for i in range(0,len(df)):
    text = df[content_field][i]
    tokens = word_tokenize(text)
    lemmatized_text = [lemmatizer.lemmatize(word) for word in tokens if not word in stopwords.words('english')]
    text = ' '.join(lemmatized_text)
    corpus.append(text)
  return corpus

# %%
for column in df.columns[:-1]:
  df[column] = lemmatization(df, column)

# %%
df.tail()
# Out:
#                                                    title  \
# 44893  mcpain john mccain furious iran treated u sail...
# 44894  justice ? yahoo settle e mail privacy class ac...
# 44895  sunnistan u allied safe zone plan take territo...
# 44896  blow 700 million al jazeera america finally ca...
# 44897  10 u.s. navy sailor held iranian military sign...
#
#                                                     text      subject  \
# 44893  21st century wire say 21wire reported earlier ...  middle east
# 44894  21st century wire say familiar theme . wheneve...  middle east
# 44895  patrick henningsen 21st century wireremember o...  middle east
# 44896  21st century wire say al jazeera america go hi...  middle east
# 44897  21st century wire say 21wire predicted new yea...  middle east
#
#                   date  reliability
# 44893  january 16 2016            0
# 44894  january 16 2016            0
# 44895  january 15 2016            0
# 44896  january 14 2016            0
# 44897  january 12 2016            0

# %%
#saving dataframe to localmemory
df.to_csv('Fake_True.csv', index = False)
